# %%
import matplotlib.pyplot as plt
import sys
sys.path.insert(0, '../')


from consonant.utils import clean_str

# %%
dataset = '../dataset/raw/raw_ratings.txt'


list_len = list()
with open(dataset, 'r', encoding='utf-8') as corpus:
    list_len = [len(clean_str(line)) for line in corpus.readlines()]

# %%
plt.hist(list_len)
plt.xlabel('char-lenght')
# Out:
# Text(0.5, 0, 'char-lenght')
